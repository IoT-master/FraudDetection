# %%
# https://stanford.edu/~shervine/blog/pytorch-how-to-generate-data-parallel
import torch
from torch.utils import data
import pandas as pd

class TestTrainSplit(data.Dataset):
    'Characterizes a dataset for PyTorch'
    def __init__(self, dataframe_x, features, dataframe_y, labels):
        'Initialization'
        super(TestTrainSplit, self).__init__()
        self.dataframe_x = dataframe_x
        self.dataframe_y = dataframe_y
        self.labels = labels
        self.list_IDs = features

    def __len__(self):
        'Denotes the total number of samples'
        return self.dataframe_x.shape[0]

    def __getitem__(self, index):
        'Generates one sample of data'
        # Load data and get label
        X = self.dataframe_x[self.list_IDs].to_numpy()[index]
        y = self.dataframe_y.to_numpy()[index]

        return X, y

# %%
# Parameters
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 2}

# %%
import numpy as np
df = pd.read_csv('HWA-Brovsi-WSA-Claims-Validated.csv', dtype={'RISK': np.float})
df = df.dropna()
df = df.drop(['Index'], axis=1)
df['ClaimTime'] = pd.DatetimeIndex(pd.to_datetime(df['CLM_DT'], format='%d/%m/%y') - pd.to_datetime(df['RCPT_DT'], format='%d/%m/%y')).day
df['DistriTime'] = pd.DatetimeIndex(pd.to_datetime(df['EA_DT'], format='%d/%m/%y') - pd.to_datetime(df['RCPT_DT'], format='%d/%m/%y')).day
# Out:
# /Users/senhmo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version
#   """
# /Users/senhmo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version

# %%
df.columns
# Out:
# Index(['EMP_ID', 'CLM_SYS', 'CLM_REF', 'WSA_TYP', 'FLEXBEN_TYPE', 'CLM_DT',
#        'CLM_YR', 'CLM_AMT', 'RCPT_DT', 'RCPT_DAY', 'DAY_TAG', 'CLM.STAT',
#        'REIMB_DT', 'REIMB_YR', 'EA_DT', 'RISK', 'ClaimTime', 'DistriTime'],
#       dtype='object')

# %%
y_value = df['RISK']
x_value = df.drop(['RISK'], axis=1)

# %%
y_value
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 31652    1.0
# 31654    0.0
# 31656    1.0
# 31660    1.0
# 31662    1.0
# Name: RISK, Length: 17271, dtype: float64

# %%
x_value = pd.get_dummies(x_value)

# %%
feature_list = list(x_value.columns)
feature_list
# Out:
# ['EMP_ID',
#  'FLEXBEN_TYPE',
#  'CLM_YR',
#  'CLM_AMT',
#  'CLM.STAT',
#  'REIMB_YR',
#  'ClaimTime',
#  'DistriTime',
#  'CLM_SYS_WSA',
#  'CLM_REF_EFSA0087157',
#  'CLM_REF_EFSA0087160',
#  'CLM_REF_EFSA0087162',
#  'CLM_REF_EFSA0087163',
#  'CLM_REF_EFSA0087164',
#  'CLM_REF_EFSA0087169',
#  'CLM_REF_EFSA0087170',
#  'CLM_REF_EFSA0087176',
#  'CLM_REF_EFSA0087178',
#  'CLM_REF_EFSA0087180',
#  'CLM_REF_EFSA0087181',
#  'CLM_REF_EFSA0087182',
#  'CLM_REF_EFSA0087183',
#  'CLM_REF_EFSA0087184',
#  'CLM_REF_EFSA0087188',
#  'CLM_REF_EFSA0087189',
#  'CLM_REF_EFSA0087190',
#  'CLM_REF_EFSA0087191',
#  'CLM_REF_EFSA0087192',
#  'CLM_REF_EFSA0087195',
#  'CLM_REF_EFSA0087198',
#  'CLM_REF_EFSA0087199',
#  'CLM_REF_EFSA0087203',
#  'CLM_REF_EFSA0087206',
#  'CLM_REF_EFSA0087207',
#  'CLM_REF_EFSA0087208',
#  'CLM_REF_EFSA0087209',
#  'CLM_REF_EFSA0087210',
#  'CLM_REF_EFSA0087211',
#  'CLM_REF_EFSA0087212',
#  'CLM_REF_EFSA0087213',
#  'CLM_REF_EFSA0087214',
#  'CLM_REF_EFSA0087215',
#  'CLM_REF_EFSA0087216',
#  'CLM_REF_EFSA0087222',
#  'CLM_REF_EFSA0087223',
#  'CLM_REF_EFSA0087224',
#  'CLM_REF_EFSA0087225',
#  'CLM_REF_EFSA0087226',
#  'CLM_REF_EFSA0087227',
#  'CLM_REF_EFSA0087228',
#  'CLM_REF_EFSA0087236',
#  'CLM_REF_EFSA0087237',
#  'CLM_REF_EFSA0087238',
#  'CLM_REF_EFSA0087239',
#  'CLM_REF_EFSA0087240',
#  'CLM_REF_EFSA0087246',
#  'CLM_REF_EFSA0087247',
#  'CLM_REF_EFSA0087248',
#  'CLM_REF_EFSA0087251',
#  'CLM_REF_EFSA0087255',
#  'CLM_REF_EFSA0087256',
#  'CLM_REF_EFSA0087257',
#  'CLM_REF_EFSA0087258',
#  'CLM_REF_EFSA0087259',
#  'CLM_REF_EFSA0087260',
#  'CLM_REF_EFSA0087261',
#  'CLM_REF_EFSA0087262',
#  'CLM_REF_EFSA0087271',
#  'CLM_REF_EFSA0087272',
#  'CLM_REF_EFSA0087273',
#  'CLM_REF_EFSA0087274',
#  'CLM_REF_EFSA0087275',
#  'CLM_REF_EFSA0087276',
#  'CLM_REF_EFSA0087277',
#  'CLM_REF_EFSA0087278',
#  'CLM_REF_EFSA0087281',
#  'CLM_REF_EFSA0087282',
#  'CLM_REF_EFSA0087284',
#  'CLM_REF_EFSA0087285',
#  'CLM_REF_EFSA0087287',
#  'CLM_REF_EFSA0087288',
#  'CLM_REF_EFSA0087289',
#  'CLM_REF_EFSA0087290',
#  'CLM_REF_EFSA0087291',
#  'CLM_REF_EFSA0087302',
#  'CLM_REF_EFSA0087303',
#  'CLM_REF_EFSA0087304',
#  'CLM_REF_EFSA0087305',
#  'CLM_REF_EFSA0087306',
#  'CLM_REF_EFSA0087307',
#  'CLM_REF_EFSA0087308',
#  'CLM_REF_EFSA0087311',
#  'CLM_REF_EFSA0087312',
#  'CLM_REF_EFSA0087317',
#  'CLM_REF_EFSA0087318',
#  'CLM_REF_EFSA0087319',
#  'CLM_REF_EFSA0087320',
#  'CLM_REF_EFSA0087321',
#  'CLM_REF_EFSA0087322',
#  'CLM_REF_EFSA0087323',
#  'CLM_REF_EFSA0087324',
#  'CLM_REF_EFSA0087325',
#  'CLM_REF_EFSA0087326',
#  'CLM_REF_EFSA0087327',
#  'CLM_REF_EFSA0087336',
#  'CLM_REF_EFSA0087337',
#  'CLM_REF_EFSA0087338',
#  'CLM_REF_EFSA0087339',
#  'CLM_REF_EFSA0087340',
#  'CLM_REF_EFSA0087341',
#  'CLM_REF_EFSA0087342',
#  'CLM_REF_EFSA0087343',
#  'CLM_REF_EFSA0087344',
#  'CLM_REF_EFSA0087345',
#  'CLM_REF_EFSA0087349',
#  'CLM_REF_EFSA0087350',
#  'CLM_REF_EFSA0087351',
#  'CLM_REF_EFSA0087352',
#  'CLM_REF_EFSA0087353',
#  'CLM_REF_EFSA0087354',
#  'CLM_REF_EFSA0087357',
#  'CLM_REF_EFSA0087359',
#  'CLM_REF_EFSA0087361',
#  'CLM_REF_EFSA0087362',
#  'CLM_REF_EFSA0087363',
#  'CLM_REF_EFSA0087364',
#  'CLM_REF_EFSA0087365',
#  'CLM_REF_EFSA0087366',
#  'CLM_REF_EFSA0087367',
#  'CLM_REF_EFSA0087368',
#  'CLM_REF_EFSA0087369',
#  'CLM_REF_EFSA0087370',
#  'CLM_REF_EFSA0087374',
#  'CLM_REF_EFSA0087375',
#  'CLM_REF_EFSA0087381',
#  'CLM_REF_EFSA0087382',
#  'CLM_REF_EFSA0087383',
#  'CLM_REF_EFSA0087384',
#  'CLM_REF_EFSA0087385',
#  'CLM_REF_EFSA0087386',
#  'CLM_REF_EFSA0087387',
#  'CLM_REF_EFSA0087388',
#  'CLM_REF_EFSA0087389',
#  'CLM_REF_EFSA0087390',
#  'CLM_REF_EFSA0087391',
#  'CLM_REF_EFSA0087392',
#  'CLM_REF_EFSA0087393',
#  'CLM_REF_EFSA0087394',
#  'CLM_REF_EFSA0087395',
#  'CLM_REF_EFSA0087396',
#  'CLM_REF_EFSA0087397',
#  'CLM_REF_EFSA0087401',
#  'CLM_REF_EFSA0087403',
#  'CLM_REF_EFSA0087408',
#  'CLM_REF_EFSA0087409',
#  'CLM_REF_EFSA0087410',
#  'CLM_REF_EFSA0087411',
#  'CLM_REF_EFSA0087412',
#  'CLM_REF_EFSA0087413',
#  'CLM_REF_EFSA0087414',
#  'CLM_REF_EFSA0087415',
#  'CLM_REF_EFSA0087416',
#  'CLM_REF_EFSA0087417',
#  'CLM_REF_EFSA0087418',
#  'CLM_REF_EFSA0087419',
#  'CLM_REF_EFSA0087420',
#  'CLM_REF_EFSA0087421',
#  'CLM_REF_EFSA0087422',
#  'CLM_REF_EFSA0087423',
#  'CLM_REF_EFSA0087424',
#  'CLM_REF_EFSA0087425',
#  'CLM_REF_EFSA0087433',
#  'CLM_REF_EFSA0087434',
#  'CLM_REF_EFSA0087435',
#  'CLM_REF_EFSA0087436',
#  'CLM_REF_EFSA0087437',
#  'CLM_REF_EFSA0087439',
#  'CLM_REF_EFSA0087440',
#  'CLM_REF_EFSA0087441',
#  'CLM_REF_EFSA0087443',
#  'CLM_REF_EFSA0087444',
#  'CLM_REF_EFSA0087446',
#  'CLM_REF_EFSA0087447',
#  'CLM_REF_EFSA0087448',
#  'CLM_REF_EFSA0087449',
#  'CLM_REF_EFSA0087450',
#  'CLM_REF_EFSA0087451',
#  'CLM_REF_EFSA0087452',
#  'CLM_REF_EFSA0087453',
#  'CLM_REF_EFSA0087454',
#  'CLM_REF_EFSA0087455',
#  'CLM_REF_EFSA0087456',
#  'CLM_REF_EFSA0087457',
#  'CLM_REF_EFSA0087463',
#  'CLM_REF_EFSA0087464',
#  'CLM_REF_EFSA0087465',
#  'CLM_REF_EFSA0087466',
#  'CLM_REF_EFSA0087467',
#  'CLM_REF_EFSA0087468',
#  'CLM_REF_EFSA0087469',
#  'CLM_REF_EFSA0087470',
#  'CLM_REF_EFSA0087471',
#  'CLM_REF_EFSA0087479',
#  'CLM_REF_EFSA0087480',
#  'CLM_REF_EFSA0087481',
#  'CLM_REF_EFSA0087482',
#  'CLM_REF_EFSA0087483',
#  'CLM_REF_EFSA0087484',
#  'CLM_REF_EFSA0087485',
#  'CLM_REF_EFSA0087486',
#  'CLM_REF_EFSA0087487',
#  'CLM_REF_EFSA0087488',
#  'CLM_REF_EFSA0087489',
#  'CLM_REF_EFSA0087490',
#  'CLM_REF_EFSA0087491',
#  'CLM_REF_EFSA0087492',
#  'CLM_REF_EFSA0087499',
#  'CLM_REF_EFSA0087500',
#  'CLM_REF_EFSA0087501',
#  'CLM_REF_EFSA0087507',
#  'CLM_REF_EFSA0087508',
#  'CLM_REF_EFSA0087509',
#  'CLM_REF_EFSA0087510',
#  'CLM_REF_EFSA0087511',
#  'CLM_REF_EFSA0087512',
#  'CLM_REF_EFSA0087513',
#  'CLM_REF_EFSA0087514',
#  'CLM_REF_EFSA0087515',
#  'CLM_REF_EFSA0087516',
#  'CLM_REF_EFSA0087517',
#  'CLM_REF_EFSA0087518',
#  'CLM_REF_EFSA0087519',
#  'CLM_REF_EFSA0087520',
#  'CLM_REF_EFSA0087521',
#  'CLM_REF_EFSA0087528',
#  'CLM_REF_EFSA0087529',
#  'CLM_REF_EFSA0087534',
#  'CLM_REF_EFSA0087536',
#  'CLM_REF_EFSA0087537',
#  'CLM_REF_EFSA0087538',
#  'CLM_REF_EFSA0087539',
#  'CLM_REF_EFSA0087540',
#  'CLM_REF_EFSA0087541',
#  'CLM_REF_EFSA0087542',
#  'CLM_REF_EFSA0087543',
#  'CLM_REF_EFSA0087544',
#  'CLM_REF_EFSA0087545',
#  'CLM_REF_EFSA0087546',
#  'CLM_REF_EFSA0087547',
#  'CLM_REF_EFSA0087557',
#  'CLM_REF_EFSA0087558',
#  'CLM_REF_EFSA0087559',
#  'CLM_REF_EFSA0087560',
#  'CLM_REF_EFSA0087569',
#  'CLM_REF_EFSA0087570',
#  'CLM_REF_EFSA0087571',
#  'CLM_REF_EFSA0087572',
#  'CLM_REF_EFSA0087573',
#  'CLM_REF_EFSA0087574',
#  'CLM_REF_EFSA0087575',
#  'CLM_REF_EFSA0087576',
#  'CLM_REF_EFSA0087577',
#  'CLM_REF_EFSA0087578',
#  'CLM_REF_EFSA0087585',
#  'CLM_REF_EFSA0087586',
#  'CLM_REF_EFSA0087596',
#  'CLM_REF_EFSA0087597',
#  'CLM_REF_EFSA0087598',
#  'CLM_REF_EFSA0087599',
#  'CLM_REF_EFSA0087600',
#  'CLM_REF_EFSA0087601',
#  'CLM_REF_EFSA0087602',
#  'CLM_REF_EFSA0087603',
#  'CLM_REF_EFSA0087604',
#  'CLM_REF_EFSA0087605',
#  'CLM_REF_EFSA0087606',
#  'CLM_REF_EFSA0087607',
#  'CLM_REF_EFSA0087608',
#  'CLM_REF_EFSA0087609',
#  'CLM_REF_EFSA0087610',
#  'CLM_REF_EFSA0087611',
#  'CLM_REF_EFSA0087615',
#  'CLM_REF_EFSA0087616',
#  'CLM_REF_EFSA0087617',
#  'CLM_REF_EFSA0087629',
#  'CLM_REF_EFSA0087630',
#  'CLM_REF_EFSA0087631',
#  'CLM_REF_EFSA0087632',
#  'CLM_REF_EFSA0087633',
#  'CLM_REF_EFSA0087634',
#  'CLM_REF_EFSA0087635',
#  'CLM_REF_EFSA0087636',
#  'CLM_REF_EFSA0087637',
#  'CLM_REF_EFSA0087638',
#  'CLM_REF_EFSA0087639',
#  'CLM_REF_EFSA0087640',
#  'CLM_REF_EFSA0087641',
#  'CLM_REF_EFSA0087642',
#  'CLM_REF_EFSA0087643',
#  'CLM_REF_EFSA0087644',
#  'CLM_REF_EFSA0087655',
#  'CLM_REF_EFSA0087656',
#  'CLM_REF_EFSA0087657',
#  'CLM_REF_EFSA0087658',
#  'CLM_REF_EFSA0087659',
#  'CLM_REF_EFSA0087670',
#  'CLM_REF_EFSA0087671',
#  'CLM_REF_EFSA0087672',
#  'CLM_REF_EFSA0087673',
#  'CLM_REF_EFSA0087674',
#  'CLM_REF_EFSA0087675',
#  'CLM_REF_EFSA0087676',
#  'CLM_REF_EFSA0087677',
#  'CLM_REF_EFSA0087678',
#  'CLM_REF_EFSA0087679',
#  'CLM_REF_EFSA0087680',
#  'CLM_REF_EFSA0087699',
#  'CLM_REF_EFSA0087700',
#  'CLM_REF_EFSA0087701',
#  'CLM_REF_EFSA0087702',
#  'CLM_REF_EFSA0087703',
#  'CLM_REF_EFSA0087704',
#  'CLM_REF_EFSA0087705',
#  'CLM_REF_EFSA0087706',
#  'CLM_REF_EFSA0087707',
#  'CLM_REF_EFSA0087708',
#  'CLM_REF_EFSA0087709',
#  'CLM_REF_EFSA0087710',
#  'CLM_REF_EFSA0087711',
#  'CLM_REF_EFSA0087712',
#  'CLM_REF_EFSA0087713',
#  'CLM_REF_EFSA0087714',
#  'CLM_REF_EFSA0087715',
#  'CLM_REF_EFSA0087716',
#  'CLM_REF_EFSA0087717',
#  'CLM_REF_EFSA0087718',
#  'CLM_REF_EFSA0087719',
#  'CLM_REF_EFSA0087720',
#  'CLM_REF_EFSA0087721',
#  'CLM_REF_EFSA0087728',
#  'CLM_REF_EFSA0087729',
#  'CLM_REF_EFSA0087730',
#  'CLM_REF_EFSA0087731',
#  'CLM_REF_EFSA0087744',
#  'CLM_REF_EFSA0087749',
#  'CLM_REF_EFSA0087750',
#  'CLM_REF_EFSA0087751',
#  'CLM_REF_EFSA0087752',
#  'CLM_REF_EFSA0087753',
#  'CLM_REF_EFSA0087754',
#  'CLM_REF_EFSA0087755',
#  'CLM_REF_EFSA0087756',
#  'CLM_REF_EFSA0087757',
#  'CLM_REF_EFSA0087758',
#  'CLM_REF_EFSA0087759',
#  'CLM_REF_EFSA0087760',
#  'CLM_REF_EFSA0087761',
#  'CLM_REF_EFSA0087762',
#  'CLM_REF_EFSA0087779',
#  'CLM_REF_EFSA0087780',
#  'CLM_REF_EFSA0087791',
#  'CLM_REF_EFSA0087792',
#  'CLM_REF_EFSA0087793',
#  'CLM_REF_EFSA0087794',
#  'CLM_REF_EFSA0087795',
#  'CLM_REF_EFSA0087796',
#  'CLM_REF_EFSA0087797',
#  'CLM_REF_EFSA0087798',
#  'CLM_REF_EFSA0087799',
#  'CLM_REF_EFSA0087800',
#  'CLM_REF_EFSA0087801',
#  'CLM_REF_EFSA0087802',
#  'CLM_REF_EFSA0087803',
#  'CLM_REF_EFSA0087804',
#  'CLM_REF_EFSA0087805',
#  'CLM_REF_EFSA0087811',
#  'CLM_REF_EFSA0087812',
#  'CLM_REF_EFSA0087813',
#  'CLM_REF_EFSA0087814',
#  'CLM_REF_EFSA0087822',
#  'CLM_REF_EFSA0087823',
#  'CLM_REF_EFSA0087827',
#  'CLM_REF_EFSA0087828',
#  'CLM_REF_EFSA0087829',
#  'CLM_REF_EFSA0087830',
#  'CLM_REF_EFSA0087831',
#  'CLM_REF_EFSA0087832',
#  'CLM_REF_EFSA0087833',
#  'CLM_REF_EFSA0087834',
#  'CLM_REF_EFSA0087835',
#  'CLM_REF_EFSA0087836',
#  'CLM_REF_EFSA0087837',
#  'CLM_REF_EFSA0087838',
#  'CLM_REF_EFSA0087839',
#  'CLM_REF_EFSA0087840',
#  'CLM_REF_EFSA0087845',
#  'CLM_REF_EFSA0087848',
#  'CLM_REF_EFSA0087850',
#  'CLM_REF_EFSA0087851',
#  'CLM_REF_EFSA0087852',
#  'CLM_REF_EFSA0087853',
#  'CLM_REF_EFSA0087854',
#  'CLM_REF_EFSA0087855',
#  'CLM_REF_EFSA0087856',
#  'CLM_REF_EFSA0087857',
#  'CLM_REF_EFSA0087858',
#  'CLM_REF_EFSA0087859',
#  'CLM_REF_EFSA0087860',
#  'CLM_REF_EFSA0087861',
#  'CLM_REF_EFSA0087862',
#  'CLM_REF_EFSA0087863',
#  'CLM_REF_EFSA0087864',
#  'CLM_REF_EFSA0087865',
#  'CLM_REF_EFSA0087866',
#  'CLM_REF_EFSA0087867',
#  'CLM_REF_EFSA0087868',
#  'CLM_REF_EFSA0087869',
#  'CLM_REF_EFSA0087870',
#  'CLM_REF_EFSA0087871',
#  'CLM_REF_EFSA0087872',
#  'CLM_REF_EFSA0087883',
#  'CLM_REF_EFSA0087885',
#  'CLM_REF_EFSA0087886',
#  'CLM_REF_EFSA0087888',
#  'CLM_REF_EFSA0087889',
#  'CLM_REF_EFSA0087890',
#  'CLM_REF_EFSA0087904',
#  'CLM_REF_EFSA0087905',
#  'CLM_REF_EFSA0087906',
#  'CLM_REF_EFSA0087907',
#  'CLM_REF_EFSA0087908',
#  'CLM_REF_EFSA0087909',
#  'CLM_REF_EFSA0087910',
#  'CLM_REF_EFSA0087911',
#  'CLM_REF_EFSA0087912',
#  'CLM_REF_EFSA0087913',
#  'CLM_REF_EFSA0087914',
#  'CLM_REF_EFSA0087915',
#  'CLM_REF_EFSA0087916',
#  'CLM_REF_EFSA0087917',
#  'CLM_REF_EFSA0087918',
#  'CLM_REF_EFSA0087919',
#  'CLM_REF_EFSA0087920',
#  'CLM_REF_EFSA0087921',
#  'CLM_REF_EFSA0087922',
#  'CLM_REF_EFSA0087923',
#  'CLM_REF_EFSA0087924',
#  'CLM_REF_EFSA0087925',
#  'CLM_REF_EFSA0087926',
#  'CLM_REF_EFSA0087927',
#  'CLM_REF_EFSA0087936',
#  'CLM_REF_EFSA0087937',
#  'CLM_REF_EFSA0087938',
#  'CLM_REF_EFSA0087939',
#  'CLM_REF_EFSA0087943',
#  'CLM_REF_EFSA0087949',
#  'CLM_REF_EFSA0087950',
#  'CLM_REF_EFSA0087951',
#  'CLM_REF_EFSA0087952',
#  'CLM_REF_EFSA0087953',
#  'CLM_REF_EFSA0087954',
#  'CLM_REF_EFSA0087955',
#  'CLM_REF_EFSA0087956',
#  'CLM_REF_EFSA0087957',
#  'CLM_REF_EFSA0087958',
#  'CLM_REF_EFSA0087959',
#  'CLM_REF_EFSA0087960',
#  'CLM_REF_EFSA0087961',
#  'CLM_REF_EFSA0087962',
#  'CLM_REF_EFSA0087963',
#  'CLM_REF_EFSA0087964',
#  'CLM_REF_EFSA0087965',
#  'CLM_REF_EFSA0087973',
#  'CLM_REF_EFSA0087974',
#  'CLM_REF_EFSA0087975',
#  'CLM_REF_EFSA0087976',
#  'CLM_REF_EFSA0087977',
#  'CLM_REF_EFSA0087978',
#  'CLM_REF_EFSA0087984',
#  'CLM_REF_EFSA0087985',
#  'CLM_REF_EFSA0087989',
#  'CLM_REF_EFSA0087990',
#  'CLM_REF_EFSA0087991',
#  'CLM_REF_EFSA0087992',
#  'CLM_REF_EFSA0087993',
#  'CLM_REF_EFSA0087994',
#  'CLM_REF_EFSA0087995',
#  'CLM_REF_EFSA0087996',
#  'CLM_REF_EFSA0087997',
#  'CLM_REF_EFSA0087998',
#  'CLM_REF_EFSA0087999',
#  'CLM_REF_EFSA0088000',
#  'CLM_REF_EFSA0088001',
#  'CLM_REF_EFSA0088002',
#  'CLM_REF_EFSA0088003',
#  'CLM_REF_EFSA0088004',
#  'CLM_REF_EFSA0088005',
#  'CLM_REF_EFSA0088006',
#  'CLM_REF_EFSA0088007',
#  'CLM_REF_EFSA0088017',
#  'CLM_REF_EFSA0088018',
#  'CLM_REF_EFSA0088019',
#  'CLM_REF_EFSA0088020',
#  'CLM_REF_EFSA0088026',
#  'CLM_REF_EFSA0088032',
#  'CLM_REF_EFSA0088033',
#  'CLM_REF_EFSA0088034',
#  'CLM_REF_EFSA0088035',
#  'CLM_REF_EFSA0088038',
#  'CLM_REF_EFSA0088039',
#  'CLM_REF_EFSA0088040',
#  'CLM_REF_EFSA0088041',
#  'CLM_REF_EFSA0088042',
#  'CLM_REF_EFSA0088043',
#  'CLM_REF_EFSA0088044',
#  'CLM_REF_EFSA0088045',
#  'CLM_REF_EFSA0088046',
#  'CLM_REF_EFSA0088047',
#  'CLM_REF_EFSA0088048',
#  'CLM_REF_EFSA0088049',
#  'CLM_REF_EFSA0088050',
#  'CLM_REF_EFSA0088051',
#  'CLM_REF_EFSA0088052',
#  'CLM_REF_EFSA0088053',
#  'CLM_REF_EFSA0088054',
#  'CLM_REF_EFSA0088055',
#  'CLM_REF_EFSA0088066',
#  'CLM_REF_EFSA0088068',
#  'CLM_REF_EFSA0088069',
#  'CLM_REF_EFSA0088070',
#  'CLM_REF_EFSA0088071',
#  'CLM_REF_EFSA0088082',
#  'CLM_REF_EFSA0088087',
#  'CLM_REF_EFSA0088088',
#  'CLM_REF_EFSA0088089',
#  'CLM_REF_EFSA0088090',
#  'CLM_REF_EFSA0088091',
#  'CLM_REF_EFSA0088093',
#  'CLM_REF_EFSA0088094',
#  'CLM_REF_EFSA0088095',
#  'CLM_REF_EFSA0088096',
#  'CLM_REF_EFSA0088097',
#  'CLM_REF_EFSA0088098',
#  'CLM_REF_EFSA0088099',
#  'CLM_REF_EFSA0088100',
#  'CLM_REF_EFSA0088101',
#  'CLM_REF_EFSA0088102',
#  'CLM_REF_EFSA0088103',
#  'CLM_REF_EFSA0088104',
#  'CLM_REF_EFSA0088110',
#  'CLM_REF_EFSA0088111',
#  'CLM_REF_EFSA0088112',
#  'CLM_REF_EFSA0088113',
#  'CLM_REF_EFSA0088121',
#  'CLM_REF_EFSA0088122',
#  'CLM_REF_EFSA0088123',
#  'CLM_REF_EFSA0088125',
#  'CLM_REF_EFSA0088127',
#  'CLM_REF_EFSA0088128',
#  'CLM_REF_EFSA0088129',
#  'CLM_REF_EFSA0088130',
#  'CLM_REF_EFSA0088131',
#  'CLM_REF_EFSA0088132',
#  'CLM_REF_EFSA0088133',
#  'CLM_REF_EFSA0088135',
#  'CLM_REF_EFSA0088136',
#  'CLM_REF_EFSA0088137',
#  'CLM_REF_EFSA0088138',
#  'CLM_REF_EFSA0088139',
#  'CLM_REF_EFSA0088140',
#  'CLM_REF_EFSA0088141',
#  'CLM_REF_EFSA0088142',
#  'CLM_REF_EFSA0088143',
#  'CLM_REF_EFSA0088144',
#  'CLM_REF_EFSA0088145',
#  'CLM_REF_EFSA0088146',
#  'CLM_REF_EFSA0088147',
#  'CLM_REF_EFSA0088148',
#  'CLM_REF_EFSA0088149',
#  'CLM_REF_EFSA0088150',
#  'CLM_REF_EFSA0088151',
#  'CLM_REF_EFSA0088152',
#  'CLM_REF_EFSA0088153',
#  'CLM_REF_EFSA0088154',
#  'CLM_REF_EFSA0088161',
#  'CLM_REF_EFSA0088162',
#  'CLM_REF_EFSA0088163',
#  'CLM_REF_EFSA0088164',
#  'CLM_REF_EFSA0088165',
#  'CLM_REF_EFSA0088172',
#  'CLM_REF_EFSA0088174',
#  'CLM_REF_EFSA0088177',
#  'CLM_REF_EFSA0088183',
#  'CLM_REF_EFSA0088184',
#  'CLM_REF_EFSA0088185',
#  'CLM_REF_EFSA0088186',
#  'CLM_REF_EFSA0088187',
#  'CLM_REF_EFSA0088188',
#  'CLM_REF_EFSA0088189',
#  'CLM_REF_EFSA0088190',
#  'CLM_REF_EFSA0088191',
#  'CLM_REF_EFSA0088192',
#  'CLM_REF_EFSA0088193',
#  'CLM_REF_EFSA0088194',
#  'CLM_REF_EFSA0088195',
#  'CLM_REF_EFSA0088196',
#  'CLM_REF_EFSA0088197',
#  'CLM_REF_EFSA0088198',
#  'CLM_REF_EFSA0088199',
#  'CLM_REF_EFSA0088200',
#  'CLM_REF_EFSA0088201',
#  'CLM_REF_EFSA0088202',
#  'CLM_REF_EFSA0088203',
#  'CLM_REF_EFSA0088214',
#  'CLM_REF_EFSA0088215',
#  'CLM_REF_EFSA0088216',
#  'CLM_REF_EFSA0088217',
#  'CLM_REF_EFSA0088228',
#  'CLM_REF_EFSA0088229',
#  'CLM_REF_EFSA0088233',
#  'CLM_REF_EFSA0088236',
#  'CLM_REF_EFSA0088237',
#  'CLM_REF_EFSA0088238',
#  'CLM_REF_EFSA0088239',
#  'CLM_REF_EFSA0088240',
#  'CLM_REF_EFSA0088241',
#  'CLM_REF_EFSA0088248',
#  'CLM_REF_EFSA0088249',
#  'CLM_REF_EFSA0088250',
#  'CLM_REF_EFSA0088251',
#  'CLM_REF_EFSA0088252',
#  'CLM_REF_EFSA0088253',
#  'CLM_REF_EFSA0088254',
#  'CLM_REF_EFSA0088255',
#  'CLM_REF_EFSA0088256',
#  'CLM_REF_EFSA0088257',
#  'CLM_REF_EFSA0088258',
#  'CLM_REF_EFSA0088259',
#  'CLM_REF_EFSA0088260',
#  'CLM_REF_EFSA0088261',
#  'CLM_REF_EFSA0088262',
#  'CLM_REF_EFSA0088263',
#  'CLM_REF_EFSA0088273',
#  'CLM_REF_EFSA0088274',
#  'CLM_REF_EFSA0088275',
#  'CLM_REF_EFSA0088276',
#  'CLM_REF_EFSA0088288',
#  'CLM_REF_EFSA0088289',
#  'CLM_REF_EFSA0088297',
#  'CLM_REF_EFSA0088298',
#  'CLM_REF_EFSA0088302',
#  'CLM_REF_EFSA0088303',
#  'CLM_REF_EFSA0088304',
#  'CLM_REF_EFSA0088305',
#  'CLM_REF_EFSA0088306',
#  'CLM_REF_EFSA0088307',
#  'CLM_REF_EFSA0088308',
#  'CLM_REF_EFSA0088309',
#  'CLM_REF_EFSA0088310',
#  'CLM_REF_EFSA0088311',
#  'CLM_REF_EFSA0088312',
#  'CLM_REF_EFSA0088313',
#  'CLM_REF_EFSA0088314',
#  'CLM_REF_EFSA0088315',
#  'CLM_REF_EFSA0088316',
#  'CLM_REF_EFSA0088317',
#  'CLM_REF_EFSA0088318',
#  'CLM_REF_EFSA0088319',
#  'CLM_REF_EFSA0088320',
#  'CLM_REF_EFSA0088321',
#  'CLM_REF_EFSA0088322',
#  'CLM_REF_EFSA0088323',
#  'CLM_REF_EFSA0088324',
#  'CLM_REF_EFSA0088332',
#  'CLM_REF_EFSA0088333',
#  'CLM_REF_EFSA0088334',
#  'CLM_REF_EFSA0088335',
#  'CLM_REF_EFSA0088336',
#  'CLM_REF_EFSA0088340',
#  'CLM_REF_EFSA0088345',
#  'CLM_REF_EFSA0088346',
#  'CLM_REF_EFSA0088347',
#  'CLM_REF_EFSA0088348',
#  'CLM_REF_EFSA0088349',
#  'CLM_REF_EFSA0088350',
#  'CLM_REF_EFSA0088351',
#  'CLM_REF_EFSA0088352',
#  'CLM_REF_EFSA0088353',
#  'CLM_REF_EFSA0088354',
#  'CLM_REF_EFSA0088355',
#  'CLM_REF_EFSA0088356',
#  'CLM_REF_EFSA0088357',
#  'CLM_REF_EFSA0088358',
#  'CLM_REF_EFSA0088364',
#  'CLM_REF_EFSA0088365',
#  'CLM_REF_EFSA0088366',
#  'CLM_REF_EFSA0088367',
#  'CLM_REF_EFSA0088368',
#  'CLM_REF_EFSA0088369',
#  'CLM_REF_EFSA0088370',
#  'CLM_REF_EFSA0088371',
#  'CLM_REF_EFSA0088372',
#  'CLM_REF_EFSA0088373',
#  'CLM_REF_EFSA0088374',
#  'CLM_REF_EFSA0088375',
#  'CLM_REF_EFSA0088376',
#  'CLM_REF_EFSA0088377',
#  'CLM_REF_EFSA0088378',
#  'CLM_REF_EFSA0088379',
#  'CLM_REF_EFSA0088380',
#  'CLM_REF_EFSA0088391',
#  'CLM_REF_EFSA0088392',
#  'CLM_REF_EFSA0088393',
#  'CLM_REF_EFSA0088394',
#  'CLM_REF_EFSA0088395',
#  'CLM_REF_EFSA0088396',
#  'CLM_REF_EFSA0088398',
#  'CLM_REF_EFSA0088399',
#  'CLM_REF_EFSA0088410',
#  'CLM_REF_EFSA0088411',
#  'CLM_REF_EFSA0088412',
#  'CLM_REF_EFSA0088413',
#  'CLM_REF_EFSA0088414',
#  'CLM_REF_EFSA0088420',
#  'CLM_REF_EFSA0088421',
#  'CLM_REF_EFSA0088422',
#  'CLM_REF_EFSA0088423',
#  'CLM_REF_EFSA0088424',
#  'CLM_REF_EFSA0088425',
#  'CLM_REF_EFSA0088426',
#  'CLM_REF_EFSA0088427',
#  'CLM_REF_EFSA0088428',
#  'CLM_REF_EFSA0088429',
#  'CLM_REF_EFSA0088430',
#  'CLM_REF_EFSA0088431',
#  'CLM_REF_EFSA0088432',
#  'CLM_REF_EFSA0088433',
#  'CLM_REF_EFSA0088434',
#  'CLM_REF_EFSA0088435',
#  'CLM_REF_EFSA0088436',
#  'CLM_REF_EFSA0088437',
#  'CLM_REF_EFSA0088438',
#  'CLM_REF_EFSA0088439',
#  'CLM_REF_EFSA0088440',
#  'CLM_REF_EFSA0088441',
#  'CLM_REF_EFSA0088448',
#  'CLM_REF_EFSA0088449',
#  'CLM_REF_EFSA0088450',
#  'CLM_REF_EFSA0088451',
#  'CLM_REF_EFSA0088452',
#  'CLM_REF_EFSA0088453',
#  'CLM_REF_EFSA0088462',
#  'CLM_REF_EFSA0088469',
#  'CLM_REF_EFSA0088470',
#  'CLM_REF_EFSA0088471',
#  'CLM_REF_EFSA0088472',
#  'CLM_REF_EFSA0088473',
#  'CLM_REF_EFSA0088474',
#  'CLM_REF_EFSA0088477',
#  'CLM_REF_EFSA0088478',
#  'CLM_REF_EFSA0088479',
#  'CLM_REF_EFSA0088480',
#  'CLM_REF_EFSA0088481',
#  'CLM_REF_EFSA0088482',
#  'CLM_REF_EFSA0088483',
#  'CLM_REF_EFSA0088484',
#  'CLM_REF_EFSA0088485',
#  'CLM_REF_EFSA0088486',
#  'CLM_REF_EFSA0088487',
#  'CLM_REF_EFSA0088488',
#  'CLM_REF_EFSA0088489',
#  'CLM_REF_EFSA0088490',
#  'CLM_REF_EFSA0088491',
#  'CLM_REF_EFSA0088492',
#  'CLM_REF_EFSA0088493',
#  'CLM_REF_EFSA0088494',
#  'CLM_REF_EFSA0088495',
#  'CLM_REF_EFSA0088502',
#  'CLM_REF_EFSA0088503',
#  'CLM_REF_EFSA0088504',
#  'CLM_REF_EFSA0088505',
#  'CLM_REF_EFSA0088508',
#  'CLM_REF_EFSA0088511',
#  'CLM_REF_EFSA0088513',
#  'CLM_REF_EFSA0088514',
#  'CLM_REF_EFSA0088515',
#  'CLM_REF_EFSA0088516',
#  'CLM_REF_EFSA0088524',
#  'CLM_REF_EFSA0088525',
#  'CLM_REF_EFSA0088526',
#  'CLM_REF_EFSA0088527',
#  'CLM_REF_EFSA0088528',
#  'CLM_REF_EFSA0088529',
#  'CLM_REF_EFSA0088530',
#  'CLM_REF_EFSA0088531',
#  'CLM_REF_EFSA0088532',
#  'CLM_REF_EFSA0088533',
#  'CLM_REF_EFSA0088534',
#  'CLM_REF_EFSA0088535',
#  'CLM_REF_EFSA0088545',
#  'CLM_REF_EFSA0088546',
#  'CLM_REF_EFSA0088547',
#  'CLM_REF_EFSA0088548',
#  'CLM_REF_EFSA0088549',
#  'CLM_REF_EFSA0088561',
#  'CLM_REF_EFSA0088565',
#  'CLM_REF_EFSA0088566',
#  'CLM_REF_EFSA0088567',
#  'CLM_REF_EFSA0088568',
#  'CLM_REF_EFSA0088569',
#  'CLM_REF_EFSA0088570',
#  'CLM_REF_EFSA0088571',
#  'CLM_REF_EFSA0088578',
#  'CLM_REF_EFSA0088579',
#  'CLM_REF_EFSA0088580',
#  'CLM_REF_EFSA0088581',
#  'CLM_REF_EFSA0088582',
#  'CLM_REF_EFSA0088583',
#  'CLM_REF_EFSA0088584',
#  'CLM_REF_EFSA0088585',
#  'CLM_REF_EFSA0088586',
#  'CLM_REF_EFSA0088587',
#  'CLM_REF_EFSA0088588',
#  'CLM_REF_EFSA0088589',
#  'CLM_REF_EFSA0088597',
#  'CLM_REF_EFSA0088598',
#  'CLM_REF_EFSA0088599',
#  'CLM_REF_EFSA0088607',
#  'CLM_REF_EFSA0088609',
#  'CLM_REF_EFSA0088610',
#  'CLM_REF_EFSA0088611',
#  'CLM_REF_EFSA0088616',
#  'CLM_REF_EFSA0088617',
#  'CLM_REF_EFSA0088618',
#  'CLM_REF_EFSA0088619',
#  'CLM_REF_EFSA0088620',
#  'CLM_REF_EFSA0088621',
#  'CLM_REF_EFSA0088622',
#  'CLM_REF_EFSA0088623',
#  'CLM_REF_EFSA0088624',
#  'CLM_REF_EFSA0088625',
#  'CLM_REF_EFSA0088626',
#  'CLM_REF_EFSA0088627',
#  'CLM_REF_EFSA0088628',
#  'CLM_REF_EFSA0088636',
#  'CLM_REF_EFSA0088637',
#  'CLM_REF_EFSA0088638',
#  'CLM_REF_EFSA0088639',
#  'CLM_REF_EFSA0088641',
#  'CLM_REF_EFSA0088655',
#  'CLM_REF_EFSA0088656',
#  'CLM_REF_EFSA0088657',
#  'CLM_REF_EFSA0088658',
#  'CLM_REF_EFSA0088659',
#  'CLM_REF_EFSA0088661',
#  'CLM_REF_EFSA0088662',
#  'CLM_REF_EFSA0088663',
#  'CLM_REF_EFSA0088664',
#  'CLM_REF_EFSA0088665',
#  'CLM_REF_EFSA0088666',
#  'CLM_REF_EFSA0088667',
#  'CLM_REF_EFSA0088668',
#  'CLM_REF_EFSA0088669',
#  'CLM_REF_EFSA0088670',
#  'CLM_REF_EFSA0088671',
#  'CLM_REF_EFSA0088672',
#  'CLM_REF_EFSA0088673',
#  'CLM_REF_EFSA0088674',
#  'CLM_REF_EFSA0088675',
#  'CLM_REF_EFSA0088676',
#  'CLM_REF_EFSA0088691',
#  'CLM_REF_EFSA0088692',
#  'CLM_REF_EFSA0088693',
#  'CLM_REF_EFSA0088694',
#  'CLM_REF_EFSA0088695',
#  'CLM_REF_EFSA0088705',
#  'CLM_REF_EFSA0088709',
#  'CLM_REF_EFSA0088710',
#  'CLM_REF_EFSA0088711',
#  'CLM_REF_EFSA0088712',
#  'CLM_REF_EFSA0088713',
#  'CLM_REF_EFSA0088714',
#  'CLM_REF_EFSA0088715',
#  'CLM_REF_EFSA0088718',
#  'CLM_REF_EFSA0088719',
#  'CLM_REF_EFSA0088720',
#  'CLM_REF_EFSA0088721',
#  'CLM_REF_EFSA0088722',
#  'CLM_REF_EFSA0088723',
#  'CLM_REF_EFSA0088724',
#  'CLM_REF_EFSA0088725',
#  'CLM_REF_EFSA0088726',
#  'CLM_REF_EFSA0088727',
#  'CLM_REF_EFSA0088728',
#  'CLM_REF_EFSA0088729',
#  'CLM_REF_EFSA0088730',
#  'CLM_REF_EFSA0088731',
#  'CLM_REF_EFSA0088732',
#  'CLM_REF_EFSA0088733',
#  'CLM_REF_EFSA0088734',
#  'CLM_REF_EFSA0088735',
#  'CLM_REF_EFSA0088736',
#  'CLM_REF_EFSA0088737',
#  'CLM_REF_EFSA0088738',
#  'CLM_REF_EFSA0088739',
#  'CLM_REF_EFSA0088750',
#  'CLM_REF_EFSA0088751',
#  'CLM_REF_EFSA0088752',
#  'CLM_REF_EFSA0088759',
#  'CLM_REF_EFSA0088762',
#  'CLM_REF_EFSA0088763',
#  'CLM_REF_EFSA0088764',
#  'CLM_REF_EFSA0088765',
#  'CLM_REF_EFSA0088766',
#  'CLM_REF_EFSA0088767',
#  'CLM_REF_EFSA0088768',
#  'CLM_REF_EFSA0088772',
#  'CLM_REF_EFSA0088773',
#  'CLM_REF_EFSA0088774',
#  'CLM_REF_EFSA0088775',
#  'CLM_REF_EFSA0088776',
#  'CLM_REF_EFSA0088777',
#  'CLM_REF_EFSA0088778',
#  'CLM_REF_EFSA0088779',
#  'CLM_REF_EFSA0088780',
#  'CLM_REF_EFSA0088781',
#  'CLM_REF_EFSA0088782',
#  'CLM_REF_EFSA0088783',
#  'CLM_REF_EFSA0088784',
#  'CLM_REF_EFSA0088785',
#  'CLM_REF_EFSA0088786',
#  'CLM_REF_EFSA0088787',
#  'CLM_REF_EFSA0088788',
#  'CLM_REF_EFSA0088797',
#  'CLM_REF_EFSA0088798',
#  'CLM_REF_EFSA0088799',
#  'CLM_REF_EFSA0088813',
#  'CLM_REF_EFSA0088815',
#  'CLM_REF_EFSA0088816',
#  'CLM_REF_EFSA0088817',
#  'CLM_REF_EFSA0088818',
#  'CLM_REF_EFSA0088819',
#  'CLM_REF_EFSA0088820',
#  'CLM_REF_EFSA0088821',
#  'CLM_REF_EFSA0088822',
#  'CLM_REF_EFSA0088823',
#  'CLM_REF_EFSA0088824',
#  'CLM_REF_EFSA0088825',
#  'CLM_REF_EFSA0088826',
#  'CLM_REF_EFSA0088827',
#  'CLM_REF_EFSA0088828',
#  'CLM_REF_EFSA0088829',
#  'CLM_REF_EFSA0088830',
#  'CLM_REF_EFSA0088831',
#  'CLM_REF_EFSA0088832',
#  'CLM_REF_EFSA0088849',
#  'CLM_REF_EFSA0088850',
#  'CLM_REF_EFSA0088851',
#  'CLM_REF_EFSA0088852',
#  'CLM_REF_EFSA0088866',
#  'CLM_REF_EFSA0088867',
#  'CLM_REF_EFSA0088868',
#  'CLM_REF_EFSA0088869',
#  'CLM_REF_EFSA0088870',
#  'CLM_REF_EFSA0088871',
#  'CLM_REF_EFSA0088875',
#  'CLM_REF_EFSA0088876',
#  'CLM_REF_EFSA0088877',
#  'CLM_REF_EFSA0088878',
#  'CLM_REF_EFSA0088879',
#  'CLM_REF_EFSA0088880',
#  'CLM_REF_EFSA0088881',
#  'CLM_REF_EFSA0088882',
#  'CLM_REF_EFSA0088883',
#  'CLM_REF_EFSA0088884',
#  'CLM_REF_EFSA0088885',
#  'CLM_REF_EFSA0088886',
#  'CLM_REF_EFSA0088887',
#  'CLM_REF_EFSA0088888',
#  'CLM_REF_EFSA0088889',
#  'CLM_REF_EFSA0088890',
#  'CLM_REF_EFSA0088891',
#  'CLM_REF_EFSA0088892',
#  'CLM_REF_EFSA0088898',
#  'CLM_REF_EFSA0088899',
#  'CLM_REF_EFSA0088900',
#  'CLM_REF_EFSA0088901',
#  'CLM_REF_EFSA0088902',
#  'CLM_REF_EFSA0088903',
#  'CLM_REF_EFSA0088904',
#  'CLM_REF_EFSA0088905',
#  'CLM_REF_EFSA0088906',
#  'CLM_REF_EFSA0088907',
#  'CLM_REF_EFSA0088908',
#  'CLM_REF_EFSA0088914',
#  'CLM_REF_EFSA0088916',
#  'CLM_REF_EFSA0088922',
#  'CLM_REF_EFSA0088923',
#  'CLM_REF_EFSA0088924',
#  'CLM_REF_EFSA0088925',
#  ...]

# %%
'RISK' in list(x_value.columns)
# Out:
# False

# %%
training_set = TestTrainSplit(x_value,feature_list, y_value, ['RISK'])

# %%
training_generator = data.DataLoader(training_set, **params)

# %%
training_generator.dataset[1]
# Out:
# (array([8.965e+03, 4.000e+00, 2.016e+03, ..., 0.000e+00, 0.000e+00,
#         1.000e+00]),
#  1.0)

# %%
import torch.nn as nn
import torch.nn.functional as F

class ANN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(in_features=64, out_features=17)
        self.fc2 = nn.Linear(in_features=17, out_features=6)
        self.output = nn.Linear(in_features=6, out_features=2)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.output(x)
        return x

# %%
model = ANN()
model
# Out:
# ANN(
#   (fc1): Linear(in_features=64, out_features=17, bias=True)
#   (fc2): Linear(in_features=17, out_features=6, bias=True)
#   (output): Linear(in_features=6, out_features=2, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
training_generator.dataset[1]
# Out:
# (array([8.965e+03, 4.000e+00, 2.016e+03, ..., 0.000e+00, 0.000e+00,
#         1.000e+00]),
#  1.0)

# %%
# # epochs = 100
# loss_arr = []
# for i,j in training_generator:
#     y_hat = model.forward(i)
#     loss = criterion(y_hat, j)
#     loss_arr.append(loss)

# #     if i % 10 == 0:
# #        print(f'Epoch: i Loss: {loss}')

#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# %%
y_hat = model.forward(torch.tensor(training_generator.dataset[0][0]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-a70e5d0257b9> in <module>
# ----> 1 y_hat = model.forward(torch.tensor(training_generator.dataset[0][0]))
#
# <ipython-input-27-28f543db570c> in forward(self, x)
#      10
#      11     def forward(self, x):
# ---> 12         x = F.relu(self.fc1(x))
#      13         x = F.relu(self.fc2(x))
#      14         x = self.output(x)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# RuntimeError: Expected object of scalar type Double but got scalar type Float for argument #2 'mat2' in call to _th_mm
